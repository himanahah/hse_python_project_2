# %% [markdown]
# Айпи гениуса

# %%
pip install requests beautifulsoup4 pandas

# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
genius_token = "E8IWyJwxnLz99mev1bTnJNnt48pOOLsT1_hfhpfYdSPTkLM5fi1ypwDrvRCC1ocx"
genius_url = "https://api.genius.com"
headers = {'Authorization': f'Bearer {genius_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}

# %% [markdown]
# тестовый запрос на расподию

# %%
search_page = requests.get('https://api.genius.com/search?q=Bohemian ',
    headers=headers)
search_page.json()
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 33,
#      'api_path': '/songs/1063',
#      'artist_names': 'Queen',
#      'full_title': 'Bohemian Rhapsody by\xa0Queen',
#      'header_image_thumbnail_url': 'https://images.genius.com/718de9d1fbcaae9f3c9b1bf483bfa8f1.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/718de9d1fbcaae9f3c9b1bf483bfa8f1.1000x1000x1.png',
#      'id': 1063,
#      'lyrics_owner_id': 3,
#      'lyrics_state': 'complete',
#      'path': '/Queen-bohemian-rhapsody-lyrics',
#      'primary_artist_names': 'Queen',
#      'pyongs_count': 701,
#      'relationships_index_url': 'https://genius.com/Queen-bohemian-rhapsody-sample',
#      'release_date_components': {'year': 1975, 'month': 10, 'day': 31},
#      'release_date_for_display': 'October 31, 1975',
#      'release_date_with_abbreviated_month_for_display': 'Oct. 31, 1975',
# ...

# %%
def search(artists_list, songs_of_art=15):
    all_songs = []
    for artist in artists_list:
        response = requests.get("https://api.genius.com/search",
            headers=headers,
            params={'q': artist, 'per_page': songs_of_art})

        if response.status_code == 200:
            hits = response.json()['response']['hits']

            for hit in hits:
                song = hit['result']
                all_songs.append({
                    'id': song['id'],
                    'title': song['title'],
                    'artist': song['primary_artist']['name'],
                    'page_views': song.get('stats', {}).get('pageviews', 0),
                    'url': song['url']})

        time.sleep(0.3)

    return all_songs

# %% [markdown]
# требуется доработка

# %%
def search(artists_list, songs_of_art=5):
    all_songs = []
    for artist in artists_list:
        response = requests.get("https://api.genius.com/search",
            headers=headers,
            params={'q': artist, 'per_page': songs_of_art})

        if response.status_code == 200:
            hits = response.json()['response']['hits']

            for hit in hits:
                song = hit['result']
                detail_response = requests.get(f"https://api.genius.com/songs/{song['id']}", headers=headers)
                detail_json = detail_response.json() if detail_response.status_code == 200 else {}
                detail = detail_json.get('response', {}).get('song', {})

                album_data = detail.get('album') or {}
                album_name = album_data.get('name', '') if album_data else ''

                all_songs.append({
                    'id': song['id'],
                    'title': song['title'],
                    'artist': song['primary_artist']['name'],
                    'page_views': song.get('stats', {}).get('pageviews', 0),
                    'url': song['url'],
                    'release_date': detail.get('release_date', ''),
                    'album': album_name,
                    'label': detail.get('label', ''),
                    'language': detail.get('language', '')})

        time.sleep(0.3)

    return all_songs

# %%
popular_artists = [
    "Drake", "Taylor Swift", "Bad Bunny", "The Weeknd", "Justin Bieber",
    "Ariana Grande", "Ed Sheeran", "Travis Scott", "Eminem", "Kanye West",
    "Rihanna", "Billie Eilish", "Post Malone", "Kendrick Lamar", "J Balvin",
    "Future", "Bruno Mars", "BTS", "Ozuna", "Juice WRLD", "Coldplay",
    "Nicki Minaj", "Chris Brown", "Dua Lipa", "XXXTENTACION", "David Guetta",
    "Imagine Dragons", "Lana Del Rey", "Daddy Yankee", "Lil Wayne", "21 Savage",
    "Rauw Alejandro", "Anuel AA", "SZA", "Khalid", "KAROL G", "Lil Baby",
    "Lady Gaga", "Maroon 5", "Beyoncé", "Maluma", "Feid", "Calvin Harris",
    "Arijit Singh", "Myke Towers", "Lil Uzi Vert", "J. Cole", "Sia",
    "Young Thug", "Linkin Park", "Doja Cat", "Shawn Mendes", "Sam Smith",
    "Shakira", "Farruko", "Peso Pluma", "Queen", "Morgan Wallen", "One Direction",
    "Metro Boomin", "Adele", "Harry Styles", "Gunna", "Arctic Monkeys",
    "Selena Gomez", "Katy Perry", "Ty Dolla $ign", "Tyler, The Creator",
    "Olivia Rodrigo", "Nicky Jam", "Halsey", "The Beatles", "Pritam",
    "Wiz Khalifa", "Playboi Carti", "Pitbull", "Die drei ???", "The Chainsmokers",
    "Marshmello", "Frank Ocean", "Junior H", "JAY-Z", "Miley Cyrus",
    "A$AP Rocky", "Cardi B", "Fuerza Regida", "Twenty One Pilots", "Camila Cabello",
    "Disney", "Sabrina Carpenter", "Avicii", "OneRepublic", "Red Hot Chili Peppers",
    "$uicideboy$", "DaBaby", "Michael Jackson", "Arcángel", "Snoop Dogg",
    "Kygo", "Sech", "Quavo", "Mac Miller", "50 Cent", "Natanael Cano",
    "Trippie Redd", "Elton John", "YoungBoy Never Broke Again", "Tyga",
    "Manuel Turizo", "Romeo Santos", "Lil Peep", "Alan Walker", "Tiësto",
    "The Neighbourhood", "Jason Derulo", "Charlie Puth", "Metallica", "Luke Combs",
    "Zach Bryan", "Kodak Black", "USHER", "Henrique & Juliano", "Bebe Rexha",
    "Justin Timberlake", "Swae Lee", "Don Omar", "Demi Lovato", "BLACKPINK",
    "Sebastian Yatra", "A Boogie Wit da Hoodie", "JHAYCO", "Pop Smoke", "Sean Paul",
    "Kali Uchis", "Daft Punk", "Big Sean", "Don Toliver", "Luis Miguel", "AC/DC",
    "Hozier", "Tate McRae", "P!nk", "Ellie Goulding", "James Arthur", "Migos",
    "Flo Rida", "Tory Lanez", "Polo G", "Akon", "Duki", "DJ Snake", "Pharrell Williams",
    "Carín León", "Nirvana", "Diplo", "G-Eazy", "Bizarrap", "Marília Mendonça",
    "Britney Spears", "Lil Durk", "Anitta", "Fleetwood Mac", "The Kid LAROI",
    "Justin Quiles", "Kid Cudi", "Black Eyed Peas", "Gucci Mane", "Green Day",
    "Offset", "Radiohead", "Bob Marley & The Wailers", "Panic! At The Disco",
    "2 Chainz", "Fall Out Boy", "Lewis Capaldi", "Roddy Ricch", "Morat", "Ne-Yo",
    "Jorge & Mateus", "Camilo", "NF", "Joji", "Martin Garrix", "Logic", "Daniel Caesar",
    "Bryson Tiller", "Lenny Tavárez", "2Pac", "Lil Nas X", "Anirudh Ravichander",
    "Charli xcx", "mgk", "John Mayer", "Major Lazer", "Megan Thee Stallion", "Wisin",
    "Stray Kids", "ROSALÍA", "PARTYNEXTDOOR", "Shreya Ghoshal", "Christian Nodal",
    "Jul", "Lil Yachty", "Childish Gambino", "Guns N' Roses", "Gorillaz", "Dr. Dre",
    "Becky G", "Rels B", "Mariah Carey", "Quevedo", "Jack Harlow", "Pink Floyd",
    "Grupo Frontera", "Macklemore", "Banda MS de Sergio Lizárraga", "5 Seconds of Summer",
    "Anne-Marie", "ZAYN", "Brent Faiyaz", "Ava Max", "Alessia Cara", "Yandel",
    "A.R. Rahman", "Mora", "Miguel", "Enrique Iglesias", "Zion & Lennox", "Robin Schulz",
    "The Rolling Stones", "Zara Larsson", "Tame Impala", "Lauv", "Michael Bublé",
    "Wisin & Yandel", "System Of A Down", "TWICE", "ABBA", "Luis R Conriquez",
    "John Legend", "Meghan Trainor", "Gusttavo Lima", "Cigarettes After Sex",
    "Chance the Rapper", "Reik", "French Montana", "Lil Tjay", "blackbear",
    "Eladio Carrion", "Alicia Keys", "Rick Ross", "Elvis Presley", "Lil Tecca",
    "Skrillex", "Bryant Myers", "Kesha", "Zedd", "Little Mix", "DJ Khaled", "Lorde",
    "Grupo Firme", "Melanie Martinez", "Ñengo Flow", "Ninho", "Madonna",
    "Creedence Clearwater Revival", "Frank Sinatra", "Noah Kahan", "Labrinth",
    "Chris Stapleton", "Paramore", "The Notorious B.I.G.", "T-Pain", "Meek Mill",
    "Darell", "Christina Aguilera", "blink-182", "Rammstein", "Slipknot",
    "Clean Bandit", "Jung Kook", "Jhené Aiko", "Summer Walker", "Troye Sivan",
    "Zé Neto & Cristiano", "U2", "Chencho Corleone", "Cris MJ", "Foo Fighters",
    "Mitski", "David Bowie", "Tainy", "Russ", "The Killers", "Bon Jovi", "Oasis",
    "League of Legends", "The 1975", "Maria Becerra", "Florida Georgia Line",
    "Wizkid", "MC Ryan SP", "Tito Double P", "Paulo Londra", "De La Ghetto", "Dalex",
    "Kehlani", "Steve Lacy", "Aventura", "Luis Fonsi", "Jeremih", "Conan Gray",
    "Matheus & Kauan", "Alok", "Led Zeppelin", "Ludacris", "Bring Me The Horizon",
    "Jonas Blue", "My Chemical Romance", "Bastille", "Måneskin", "Marc Anthony",
    "The Lumineers", "Plan B", "Anderson .Paak", "Central Cee", "Burna Boy", "YG",
    "Nickelback", "Danny Ocean", "Julia Michaels", "Mac DeMarco", "Yeat",
    "Sfera Ebbasta", "Luke Bryan", "NATTI NATASHA", "Maná", "Florence + The Machine",
    "NAV", "NLE Choppa", "Juanes", "Timbaland", "La Arrolladora Banda El Limón De Rene Camacho",
    "Muse", "Hans Zimmer", "Vishal-Shekhar", "Chase Atlantic", "Jonas Brothers",
    "Tove Lo", "Cartel De Santa", "T.I.", "Billy Joel", "Jennifer Lopez", "Benson Boone",
    "GIVĒON", "Prince Royce", "Bruce Springsteen", "El Alfa", "Lost Frequencies",
    "Bonez MC", "Whitney Houston", "Jack Johnson", "Beéle", "Glass Animals", "DJ Luian",
    "Amy Winehouse", "Julián Álvarez y su Norteño Banda", "Gracie Abrams", "Alejandro Sanz",
    "Avril Lavigne", "SEVENTEEN", "Gabito Ballesteros", "Tanishk Bagchi", "Niall Horan",
    "6ix9ine", "Clairo", "Fetty Wap", "Alejandro Fernández", "Felix Jaehn", "RAYE",
    "Kings of Leon", "TINI", "Oscar Maydon", "Alfredo Olivas", "Mark Ronson", "Jimin",
    "Stevie Wonder", "The Script", "Mambo Kingz", "Piso 21", "Rae Sremmurd", "Kelly Clarkson",
    "Bon Iver", "Nate Dogg", "The Offspring", "Juicy J", "6LACK", "Aerosmith", "Vance Joy",
    "Jess Glynne", "Bibi Blocksberg", "Backstreet Boys", "Joan Sebastian", "Calibre 50",
    "Bee Gees", "RAF Camora", "Rita Ora", "ScHoolboy Q", "Alesso", "Dave", "Eslabon Armado",
    "Kevin Gates", "Rod Wave", "Brytiago", "Jay Wheeler", "Disclosure", "Amitabh Bhattacharya",
    "Kane Brown", "TV Girl", "Three Days Grace", "Rex Orange County", "Vicente Fernández",
    "Noriel", "Deftones", "Wesley Safadão", "Eagles", "Ana Castela", "H.E.R.", "The Strokes",
    "Teddy Swims", "Ricardo Arjona", "Avenged Sevenfold", "Disturbed", "GIMS", "Sachin-Jigar",
    "Nelly", "Mumford & Sons", "Maiara & Maraisa", "Los Ángeles Azules", "Phil Collins",
    "Five Finger Death Punch", "Chappell Roan", "NewJeans", "Pearl Jam", "The Police",
    "Johnny Cash", "KHEA", "Tiago PZK", "Macklemore & Ryan Lewis", "Thomas Rhett", "MØ",
    "Dire Straits", "The Smiths", "Nicki Nicole", "Steve Aoki", "Calum Scott", "Céline Dion",
    "Ryan Lewis", "Dean Lewis", "JID", "Moneybagg Yo", "Jason Aldean", "Neton Vega",
    "YNW Melly", "Hailee Steinfeld", "Bryan Adams", "Nelly Furtado", "Bazzi", "benny blanco",
    "Jason Mraz", "Tom Odell", "LANY", "Blessd", "Alec Benjamin", "Luan Santana",
    "TOMORROW X TOGETHER", "beabadoobee", "Zion", "Lizzo", "Original Broadway Cast of Hamilton",
    "Ski Mask The Slump God", "Morad", "Atif Aslam", "Outkast", "B.o.B", "Bibi und Tina",
    "Grupo Marca Registrada", "Mustard", "Milo j", "Train", "Korn", "will.i.am", "Irshad Kamil",
    "Mc IG", "Jesse & Joy", "MGMT", "Luciano", "Alka Yagnik", "Juan Gabriel", "The Cure",
    "Trey Songz", "Fifth Harmony", "Damso", "ENHYPEN", "JENNIE", "George Ezra", "Los Temerarios",
    "Pablo Alborán", "iann dior", "Karan Aujla", "Gera MX", "Ricky Martin", "Chief Keef",
    "Ovy On The Drums", "Matuê", "Marco Antonio Solís", "Lin-Manuel Miranda", "Ryan Castro",
    "Phoebe Bridgers", "Armin van Buuren", "Limp Bizkit", "AFROJACK", "Rich The Kid",
    "José José", "d4vd", "Baby Keem", "Los Tigres Del Norte", "Filipe Ret", "Cage The Elephant",
    "Capital Bra", "Flume", "Soda Stereo", "Juan Luis Guerra 4.40", "Udit Narayan", "Cosculluela",
    "Swedish House Mafia", "MEDUZA", "Glee Cast", "R3HAB", "Journey", "24kGoldn", "NIKI",
    "Lord Huron", "A$AP Ferg", "John Williams", "Empire Of The Sun", "Dominic Fike", "AJR",
    "Gwen Stefani", "LUDMILLA", "Marvin Gaye", "X Ambassadors", "James Bay", "Galantis",
    "Tyler Childers", "Santa Fe Klan", "Trueno", "Bob Dylan", "Cazzu", "The Cranberries",
    "Luísa Sonza", "Young Miko", "Jelly Roll", "Nio Garcia", "Gerardo Ortiz", "Daya",
    "Lunay", "Becky Hill", "Alemán", "Rema", "The Game", "Laufey", "bbno$", "Skillet",
    "Jessie J", "Depeche Mode", "Nas", "Grupo Menos É Mais", "KK", "King Von", "Foster The People",
    "Diddy", "Tones And I", "Weezer", "Carlos Vives", "Madison Beer", "Jax Jones", "Aitana",
    "V", "Lucenzo", "Lil Jon", "Cheat Codes", "Lil Skies", "Emilia", "Kumaar", "Hillsong Worship",
    "Skepta", "Earth, Wind & Fire", "TOTO", "Ha*Ash", "Dan + Shay", "Manoj Muntashir", "Arcane",
    "Hugo & Guilherme", "Daryl Hall & John Oates", "Paul McCartney", "Iron Maiden", "AP Dhillon",
    "Lukas Graham", "Wale", "Mc Don Juan", "Jubin Nautiyal", "Los Tucanes De Tijuana", "Shaggy",
    "Zac Brown Band", "Ice Cube", "C. Tangana", "Blake Shelton", "Eric Church", "Wyclef Jean",
    "Mon Laferte", "ILLENIUM", "PNL", "Julieta Venegas", "Ludovico Einaudi", "Passenger",
    "Lil Pump", "PnB Rock", "Badshah", "Black Sabbath", "Rod Stewart", "Diljit Dosanjh", "MARINA",
    "Sleepy Hallow", "Pusha T", "White Noise Radiance", "Guè", "The Doors", "Maren Morris",
    "Mrs. GREEN APPLE", "Latto", "James Blunt", "PinkPantheress", "LE SSERAFIM", "Papa Roach",
    "DJ Nelson", "The Marías", "Topic", "girl in red", "Carly Rae Jepsen", "Noah Cyrus", "R.E.M.",
    "Lyanno", "Kacey Musgraves", "Iggy Azalea", "Stormzy", "Destiny's Child", "Ufo361", "Key Glock",
    "Tim McGraw", "Seeb", "Lil Mosey", "Tinashe", "George Michael", "Lazza", "Geolier", "Pentatonix",
    "Natalia Lafourcade", "Christina Perri", "Mithoon", "MC Cabelinho", "Joey Bada$$", "The Beach Boys",
    "Evanescence", "Jorja Smith", "Enya", "Gzuz", "The Black Keys", "Elevation Worship", "Chino Pacas",
    "YOASOBI", "MF DOOM", "Kenny Chesney", "Mike Posner", "aespa", "El Fantasma", "Milky Chance",
    "Van Morrison", "Norah Jones", "Lynyrd Skynyrd", "Charlie Brown Jr.", "Jeremy Zucker", "Melendi",
    "Dei V", "LISA", "JVKE", "Bruno & Marrone", "D-Block Europe", "ROSÉ", "Sonu Nigam", "Dean Martin",
    "Sigala", "Zoé", "Niska", "Kid Ink", "Los Bukis", "George Strait", "Ella Henderson", "Jaden",
    "Capo Plaza", "Ruth B.", "Sade", "Leslie Odom Jr.", "Yo Yo Honey Singh", "Orochi", "Keane",
    "Busta Rhymes", "Eric Clapton", "Adam Levine", "Stromae", "Sam Hunt", "Ms. Lauryn Hill",
    "Carlos Rivera", "Jeezy", "Rise Against", "Birdy", "Ray Dalton", "Dolly Parton", "Simon & Garfunkel",
    "Imanbek", "The Goo Goo Dolls", "Mainstreet", "Mau y Ricky", "Robbie Williams", "Ozzy Osbourne",
    "keshi", "Bill Withers", "Sido", "alt-J", "Die drei ??? Kids", "CNCO", "Dimitri Vegas & Like Mike",
    "Rudimental", "Scorpions", "Juan Magán", "MC Hariel", "Van Halen", "Carrie Underwood", "Marracash",
    "Sam Feldt", "Veigh", "Ferrugem", "Sid Sriram", "Alan Jackson", "i-dle", "Jon Pardi",
    "Banda El Recodo", "Yuvan Shankar Raja", "Gente De Zona", "Juhn", "Breaking Benjamin",
    "Tears For Fears", "AURORA", "Leon Bridges", "The Smashing Pumpkins", "Dermot Kennedy",
    "Aya Nakamura", "WILLOW", "Gazo", "Hillsong UNITED", "Fred again..", "Darshan Raval", "Dilsinho",
    "Booba", "Canserbero", "Denzel Curry", "Jowell & Randy", "Shubh", "The Fray", "Sublime", "Tulus",
    "KISS", "Joel Corry", "Neha Kakkar", "Shania Twain", "Gustavo Mioto", "Dream Supplier", "Jay Chou",
    "Young Dolph", "Alice In Chains", "La Oreja de Van Gogh", "Missy Elliott", "Almighty", "Ivan Cornejo",
    "Alex Warren", "Vishal Mishra", "Shankar Mahadevan", "Bradley Cooper", "Kim Petras", "Sabaton",
    "Dadju", "FloyyMenor", "Tems", "Joyner Lucas", "Gabry Ponte", "Mohit Chauhan", "Dido", "Chayanne",
    "BigXthaPlug", "Shinedown", "Ghost", "BONES", "Yuridia", "Boyce Avenue", "Elley Duhé",
    "Rage Against The Machine", "Oliver Tree", "Xavi", "La Adictiva", "Sum 41", "The White Stripes",
    "Rain Sounds", "Jay Rock", "SAINt JHN", "Keith Urban", "Hungria", "Bing Crosby", "Cody Johnson",
    "SCH", "Background White Noise", "Baby Sleeps", "Volbeat", "L7NNON", "Alex Rose", "CeeLo Green",
    "Dímelo Flow", "Nat King Cole", "Magenta", "Sting", "Xamã", "Ken Carson", "Axwell", "David Bisbal",
    "Vishal Dadlani", "Normani", "Brray", "DNCE", "Sunidhi Chauhan", "Olly Alexander (Years & Years)",
    "White Noise Baby Sleep", "Pierce The Veil", "Kevin Kaarl", "Guilherme & Benuto", "JP Cooper",
    "Aminé", "Sorriso Maroto", "The Vamps", "S. P. Balasubrahmanyam", "Jimi Hendrix", "Ciara",
    "KayBlack", "Intocable", "Prince", "PLK", "3 Doors Down", "Os Barões Da Pisadinha",
    "Electric Light Orchestra", "Cali Y El Dandee", "Ella Mai", "Diego & Victor Hugo", "Murilo Huff",
    "Continental", "Luan Pereira", "Falling In Reverse", "EXO", "Wham!", "Shiva", "Mary J. Blige",
    "All Time Low", "Idina Menzel", "Shiloh Dynasty", "Omar Courtz", "Kontra K", "a-ha", "Lata Mangeshkar",
    "BROCKHAMPTON", "Kodaline", "Kylie Minogue", "MNEK", "Yo Gotti", "Sebastian Ingrosso", "Danna Paola",
    "Red Velvet", "Sidhu Moose Wala", "Liam Payne", "Odetari", "Stephen Sanchez", "Marilyn Manson",
    "Roxette", "M83", "Skylar Grey", "YUNGBLUD", "Los Dos Carnales", "Los Enanitos Verdes", "Nekfeu",
    "La Santa Grifa", "Amit Trivedi", "Mc Kevin", "UZI", "Willie Nelson", "Beach House", "Ashanti",
    "Bronco", "Aretha Franklin", "Saweetie", "Rvssian", "Apache 207", "Johann Sebastian Bach",
    "Mother Mother", "Mötley Crüe", "Jessie Reyez", "MC Kevin o Chris", "A Day To Remember",
    "Jesús Adrián Romero", "Zendaya", "KPop Demon Hunters Cast", "Eden Muñoz", "MC PH", "DMX",
    "Bethel Music", "Sin Bandera", "LUCKI", "PNAU", "Why Don't We", "Israel & Rodolffo", "Rag'n'Bone Man",
    "j-hope", "ANAVITÓRIA", "Sufjan Stevens", "Carla Morrison", "Ice Spice", "CRO", "Annie Lennox",
    "Shilpa Rao", "KEVIN ROLDAN", "Internet Money", "Andy Grammer", "Sezen Aksu", "Sean Kingston",
    "Benjamin Blümchen", "Sachet Tandon", "WALK THE MOON", "RÜFÜS DU SOL", "Hindia", "Thiaguinho",
    "Fergie", "ODESZA", "Camila", "Lauana Prado", "Kany García", "B Praak", "Doechii", "Casper Magico",
    "Santana", "Pedro Capó", "YSY A", "Mabel", "Calle 24", "The Clash", "Jordan Davis", "Gryffin",
    "Gloria Trevi", "Zac Efron", "John Newman", "Tiakola", "Silk Sonic", "John Lennon", "NCT DREAM",
    "The Pussycat Dolls", "Rascal Flatts", "Olivia O'Brien", "Of Monsters and Men", "ATEEZ",
    "Rahat Fateh Ali Khan", "Mari Fernandez", "Mc Gw", "*NSYNC", "Westlife", "Kelsea Ballerini",
    "Hollywood Undead", "Tego Calderón", "BoyWithUke", "LIT killah", "Cyndi Lauper", "Nile Rodgers",
    "Salmo", "Jon Bellion", "Pepe Aguilar", "Naps", "Pineapple StormTv", "Queens of the Stone Age",
    "Jaani", "Louis Armstrong", "Jere Klein", "Cavetown", "Mike WiLL Made-It", "Beret", "Boney M.",
    "Miranda Lambert", "Kenshi Yonezu", "Felipe Amorim", "Gustavo Cerati", "London Symphony Orchestra",
    "Gesaffelstein", "Nanpa Básico", "Tech N9ne", "Ja Rule", "The xx", "HARDY", "Maes",
    "Wolfgang Amadeus Mozart", "Harris Jayaraj", "Nick Jonas", "Tedua", "Ezhel", "Grey", "J Alvarez",
    "Wallows", "Hombres G", "Goodboys", "Ana Gabriel", "Dread Mar I", "Kenia Os", "Eyedress", "Tony Dize",
    "Soolking", "Taio Cruz", "Simone Mendes", "Laura Pausini", "Two Feet", "Sleeping At Last", "Tina Turner",
    "Ella Fitzgerald", "Vairamuthu", "João Gomes", "Otis Redding", "Jon Z", "Ghostemane", "Tee Grizzley",
    "Kunaal Vermaa", "G. V. Prakash", "Agust D", "Colbie Caillat", "Dallass", "Owl City", "Lenny Kravitz",
    "Lionel Richie", "DENNIS", "Gigi D'Agostino", "Cristian Castro", "FISHER", "Two Door Cinema Club",
    "Armaan Malik", "Lee Brice", "NATTAN", "OFFICIAL HIGE DANDISM", "R. Kelly", "Toby Fox", "Tyla",
    "Semicenk", "Miky Woodz", "Thalia", "Samra", "Kishore Kumar", "Lvbel C5", "Tracy Chapman", "Yung Gravy",
    "Ado", "Rich Brian", "Dimitri Vegas", "Incubus", "Old Dominion", "Bailey Zimmerman", "Bad Gyal",
    "MC GP", "Sasha Alex Sloan", "Toby Keith", "thasup", "Thirty Seconds To Mars", "Cardenales De Nuevo León",
    "Brooks & Dunn", "ITZY", "Los Invasores De Nuevo León", "Selena", "Tom Petty", "Bunbury", "HUGEL",
    "PEDRO SAMPAIO", "Calle 13", "KALEO", "SAIKO", "IU", "Kumar Sanu", "MC Tuto", "Nimo", "Gemitaiz",
    "KAYTRANADA", "Kungs", "G Herbo", "RADWIMPS", "Natasha Bedingfield", "Dierks Bentley", "Zé Felipe",
    "Supernova Ent", "Rvfv", "Andrés Calamaro", "Jin", "RM", "Yusuf / Cat Stevens", "Pabllo Vittar",
    "Regard", "Sleep Token", "Tulsi Kumar", "Belinda", "Lily Allen", "Die Kita-Frösche", "Simone Sommerland",
    "Chelsea Cutler", "Bomba Estéreo", "Davido", "Snow Patrol", "Karsten Glück", "Rafa Pabön", "Amaal Mallik",
    "Foreigner", "Dove Cameron", "Mc Davi", "Hugh Jackman", "IVE", "Travis Barker", "Ayra Starr", "Rochak Kohli",
    "Vince Staples", "Sexyy Red", "Portugal. The Man", "Alvaro Diaz", "Greeicy", "Dardan", "TLC", "Ofenbach",
    "James Blake", "Alex G", "C.R.O", "Caifanes", "El Komander", "Willy William", "Ali Gatie", "Ke Personajes",
    "ZZ Top", "ONE OK ROCK", "Manu Chao", "David Kushner", "Axwell /\ Ingrosso", "The Kooks", "Hariharan",
    "back number", "Novo Amor", "WIU", "Louis Tomlinson", "E-40", "Oh Wonder", "Werenoi", "Victor Mendivil",
    "Creed", "Stefflon Don", "Lil Tracy", "Chinmayi", "Pixies", "Ben&Ben", "Conjunto Primavera", "SYML",
    "Turma do Pagode", "Mc Livinho", "Rich Homie Quan", "Timmy Trumpet", "42 Dugg", "Asees Kaur", "Frédéric Chopin",
    "Loud Luxury", "Kelly Rowland", "Jaymes Young", "Andrea Bocelli", "Summer Cem", "Tayc", "Bea Miller",
    "Danger Mouse", "Purple Disco Machine", "Blur", "Blueface", "Desiigner", "KYLE", "Matoma", "Jasmine Thompson",
    "Simple Plan", "NCT 127", "MAGIC!", "Lady A", "The Who", "sombr", "Daveed Diggs", "Montell Fish", "Pantera",
    "Teto", "Taco Hemingway", "Shaboozey", "Paul Simon", "Moby", "Kate Bush", "Vintage Culture", "Supertramp",
    "T3R Elemento", "Riley Green", "Audioslave", "GloRilla", "Cher", "Beastie Boys", "Quinn XCII", "Hotel Ugly",
    "fun.", "Nina Simone", "NEFFEX", "Grupo Bryndis", "Megadeth", "Banda Los Recoditos", "Gotye", "The Jackson 5",
    "Hamza", "gnash", "Jamie Foxx", "Duelo", "Kimbra", "Luar La L", "Rashmi Virag", "The Living Tombstone", "TOOL",
    "De La Soul", "Na.Muthukumar", "Artemas", "Gurinder Gill", "MAX", "Karthik", "A7S", "Jungle",
    "Los Dareyes De La Sierra", "Hippie Sabotage", "AJ Tracey", "Young Nudy", "Lofi Fruits Music", "Salve Malak",
    "John Denver", "Djadja & Dinaz", "Mahalini", "Gym Class Heroes", "INNA", "Joaquín Sabina", "Sofía Reyes",
    "Hardwell", "Evaluna Montaner", "Estopa", "UB40", "Soulja Boy", "Don Diablo", "SDM", "Café Tacvba", "Baby Gang",
    "Thundercat", "Lauren Daigle", "Patrick Watson", "Nadin Amizah", "Omah Lay", "Rocío Dúrcal", "Shankar-Ehsaan-Loy",
    "Ben Howard", "OMI", "Blondie", "Natiruts", "Kollegah", "Miranda!", "Jenni Rivera", "Chris Young", "Lykke Li",
    "Ricardo Montaner", "Vampire Weekend", "Virlan Garcia", "Khruangbin", "Asake", "Eros Ramazzotti", "Manuel Medrano",
    "Nacho", "Shoreline Mafia", "Nipsey Hussle", "Seether", "Øneheart", "Sky Rompiendo", "Leona Lewis", "Dave Stewart",
    "Fabolous", "Surfaces", "Oruam", "Talking Heads", "C418", "Ed Maverick", "Â¥$", "Spice Girls", "Fujii Kaze",
    "Ultimo", "Olly Murs", "Himesh Reshammiya", "Luck Ra", "Aloe Blacc", "Max Richter", "Billy Idol", "Cuco",
    "Masego", "The Score", "Jessie Murph", "Air Supply", "Fat Joe", "Duran Duran", "Juicy Luicy", "Beny Jr",
    "Counting Crows", "Sandro Cavazza", "Kenny Rogers", "Guaynaa", "Bullet For My Valentine", "Dhanush", "Trevor Daniel",
    "Devi Sri Prasad", "Chicago", "Big Ali", "Sheila On 7", "Chris Jedi", "LMFAO", "Chalino Sanchez", "W&W",
    "Eurythmics", "Jacquees", "Coi Leray", "Freddie Dredd", "Ashnikko", "Tori Kelly", "Deorro", "Antonio Aguilar",
    "Franco De Vita", "CKay", "Willie Colón", "M.I.A.", "EJAE", "Earl Sweatshirt", "Bo Burnham", "Micro TDH",
    "Def Leppard", "Djonga", "Kordhell", "Edgardo Nuñez", "Neil Young", "INXS", "Julio Iglesias", "REI AMI", "Ñejo",
    "Tito \"El Bambino\"", "Lily-Rose Depp", "Vaundy", "Jarabe De Palo", "Pashanim", "Dynoro", "Coolio", "JC Reyes",
    "MC Kevinho", "Majid Jordan", "Neeti Mohan", "Marca MP", "Tom Petty and the Heartbreakers", "Ronnie Flex", "BØRNS",
    "Mc Paiva ZS", "Will Smith", "Janelle Monáe", "Santhosh Narayanan", "MKTO", "BLOK3", "Lupe Fiasco", "Fonseca",
    "Pamungkas", "Ray Charles", "Los Cadetes De Linares", "White 2115", "Selena Gomez & The Scene", "Río Roma",
    "Ángela Aguilar", "Pouya", "Tiara Andini", "The Walters", "Miguel Bosé", "Sara Bareilles", "Antônio Carlos Jobim",
    "VIZE", "Imogen Heap", "Vulgo FK", "The National", "Lil Kleine", "Lenin Ramírez", "Carpenters", "Bausa", "$NOT",
    "Pablo Chill-E", "Lainey Wilson", "Grimes", "deadmau5", "Icona Pop", "Valentín Elizalde", "León Larregui",
    "Wu-Tang Clan", "Fivio Foreign", "Angus & Julia Stone", "No Doubt", "Lizzy McAlpine", "Alanis Morissette",
    "Martin Solveig", "Wall Hein", "WOS", "Djo", "Parampara Tandon", "Flo Milli", "Ariel Camacho y Los Plebes Del Rancho",
    "Arizona Zervas", "I Prevail", "Maite Perroni", "Rainbow Kitten Surprise", "Babasonicos", "Alvaro Soler",
    "The Greatest Showman Ensemble", "Ella Eyre", "Mc Poze do Rodo", "Roberto Carlos", "Lalo Ebratt", "Sleepy John",
    "Arcade Fire", "Method Man", "Soundgarden", "Mr. Probz", "Waka Flocka Flame", "070 Shake", "The Temptations",
    "Emmanuel", "Kina", "Quality Control", "Blxst", "Yan Block", "Zezé Di Camargo & Luciano", "Pink Sweat$", "Javed Ali",
    "Vacations", "Rkomi", "Lefty Sm", "Lacrim", "Descemer Bueno", "Thaman S", "Bedoes 211", 'Tz da Coronel', 'Tinie Tempah', 'The All-American Rejects', 'The Doobie Brothers', 'AUDREY NUNA',
   'Brantley Gilbert', 'Night Lovell', 'Upchurch', 'Léo Santana', 'Brad Paisley',
   'Brett Young', 'Keyshia Cole', 'Cults', 'Isabel LaRosa', 'Damian Marley',
   'Chris Tomlin', 'Rusherking', 'BIGBANG', 'Ramin Djawadi', 'Darius Rucker',
   'Grupo Laberinto', 'Jamiroquai', 'Lary Over', 'Tion Wayne', 'Xand Avio',
   'Sam Cooke', 'Jimmy Eat World', 'John Martin', 'Godsmack', 'Survivor',
   'Racionais MC\'s', 'Legião Urbana', 'BK', 'Surf Curse', 'Keri Hilson',
   'Mata', 'Ludwig van Beethoven', 'Crystal Castles', 'Oliver Heldens', 'K. S. Chithra',
   'Kid Rock', 'Billy Ray Cyrus', 'Leo Dan', 'Tarcísio do Acordeon', 'Bob Sinclar',
   'Cypress Hill', 'Coez', 'Anuv Jain', 'Pooh Shiesty', 'Baby Rasta',
   'City Girls', 'America', 'Cole Swindell', 'LP', 'Lola Indigo',
   'Kidz Bop Kids', 'Stone Temple Pilots', 'Péricles', 'Koe Wetzel', 'Okieriete Onaodowan',
   'Ikky', 'MK', 'Charles Ans', 'Matchbox Twenty', 'Dustin Lynch',
   'Astrid S', 'Yxng Bane', 'Genesis', 'Angèle', 'Guru Randhawa',
   'James Taylor', 'Kapo', 'Neil Diamond', 'Boyz II Men', 'Jonita Gandhi',
   'Kidd Keo', 'Etta James', 'No Te Va Gustar', 'Olivia Dean', 'Ati242',
   'Alejandra Guzman', 'Pinguini Tattici Nucleari', 'Gregory Alan Isakov', 'FINNEAS', '88rising',
   'Martin Jensen', 'L.V.', 'Ricky Montgomery', 'Conor Maynard', 'Steely Dan',
   'Los Fabulosos Cadillacs', 'Adolescent\'s Orquesta', 'Motive', 'Gabriela Rocha', 'A Tribe Called Quest',
   'Connor Price', 'Mario', 'Franz Ferdinand', 'Nagalli', 'Maverick City Music',
   'Billy Currington', 'Baco Exu do Blues', 'Sachet-Parampara', 'Modern Talking', 'Frenna',
   'HUNTR/X', 'King Gnu', 'Bad Omens', 'Benny Dayal', 'Cordae',
   'Tom Walker', 'Bonnie Tyler', 'Ashe', 'Maggie Rogers', 'Mägo de Oz',
   'Omar Montes', 'Kenny Loggins', 'Takeoff', 'Sage The Gemini', 'Ratatat',
   'Dennis Lloyd', 'Koba LaD', 'Erykah Badu', 'CHVRCHES', 'Young the Giant',
   'The Alchemist', 'Aitch', 'Christopher Jackson', 'Matisse', 'Masoom Sharma',
   'Robin Thicke', 'Antonio Vivaldi', 'Riton', 'Simply Red', 'MERO',
   'AnnenMayKantereit', 'HUMBE', 'Waylon Jennings', 'HAIM', 'King',
   'Fireboy DML', 'Dreamville', 'Capital Cities', 'Emeli Sandé', 'James TW',
   'Yelawolf', 'Orelsan', 'Beck', 'Jasiel Nuñez', 'Lil Dicky',
   'Brenda Lee', 'Elefante', 'Jack Joseph Puig', 'Phillipa Soo', 'GoldLink',
   'Zacari', 'Keala Settle', 'MIKA', 'Los Inquietos Del Norte', 'Grupo Niche',
   'Tommy Richman', 'Yorushika', 'MC Joozinho VT', 'Anahí', 'Olivia Newton-John',
   'Melim', 'Jimmy Buffett', 'George Harrison', 'Los Auténticos Decadentes', 'Em Beihold',
   'Simone & Simaria', 'Jory Boy', 'Chuck Berry', 'TAYA', 'Crookers',
   'Paloma Faith', 'Isaiah Rashad', 'Lloyd', 'KC Rebell', 'Aimyon',
   'Hev Abi', 'Dulce María', 'KSI', 'De La Rose', 'Alexis y Fido',
   'Lennon Stella', 'Arthur Nery', 'Sofia Carson', 'Randy Nota Loca', 'Duke Dumont',
   'BIA', 'AYLIVA', 'Héctor "El Father"', 'Sam Fender', 'Azet',
   'The Verve', 'FMK', 'Vaali', 'Los Plebes del Rancho de Ariel Camacho', 'Lola Young',
   'Jasleen Royal', 'MC Marks', 'James Hype', 'Bob Seger', 'Men I Trust',
   'Pesado', 'Fabri Fibra', 'Mike Perry', 'Pet Shop Boys', 'Moira Dela Torre',
   'Eve', 'Edwin Luna y La Trakalosa de Monterrey', 'Polimá Westcoast', 'LiSA', 'Deep Purple',
   'Ghali', 'Nikhita Gandhi', 'Last Child', 'Gloria Groove', 'Far East Movement',
   'Neto Peña', 'Myles Smith', 'Heart', 'Caetano Veloso', 'Grateful Dead',
   'Brando', 'C-Kan', 'JP Saxe', 'Fitz and The Tantrums', 'Banda Sinaloense MS de Sergio Lizárraga',
   'Luché', 'DannyLux', 'Nate Ruess', 'The Chicks', 'Smash Mouth',
   'Boef', 'RBD', 'Omar Varela', 'Alonzo', 'Indila',
   'Omar Apollo', 'Maxwell', 'Yng Lvcas', 'J Hus', 'Bacilos',
   'Pedro Lotto', 'Seafret', 'Haze', 'Lindsey Stirling', 'MC Cebezinho',
   'LSD', 'James Brown', 'HWASA', 'Arjan Dhillon', 'wave to earth',
   'Steven Universe', 'Destroy Lonely', 'Freddie Gibbs', 'Jake Owen', 'Ilaiyaraaja',
   'Brandon Lake', 'The Paper Kites', 'Digital Farm Animals', 'BENEE', 'Taiu',
   'Lomepal', 'Juanka', 'Greta Van Fleet', 'Jorge Rivera-Herrans', 'Kiiara',
   'Ana Mena', 'LATIN MAFIA', 'Christian Chávez', 'Alphaville', 'The Kinks',
   'Tokischa', 'Madlib', 'Kausar Munir', 'Xavier Wulf', 'Hayley Williams',
   'Sheff G', 'London Grammar', 'Yo-Yo Ma', 'Zé Vaqueiro', 'Disciples',
   'Pinkfong', 'Pras', 'Silvestre Dangond', 'Craig David', 'reezy',
   'María José', 'Roy Orbison', 'Christopher von Uckermann', 'Colby O\'Donis', 'The-Dream',
   'Ruel', 'Kool & The Gang', 'Gigi Perez', 'Jay Sean', 'Mobb Deep',
   'Bernadya', 'MadeinTYO', 'MC Davo', 'RIN', 'Royal Philharmonic Orchestra',
   'Bas', 'Beach Bunny', 'Steve Miller Band', 'Simple Minds', 'GROUPLOVE',
   'Dance Fruits Music', 'Fernandinho', 'Gilberto Santa Rosa', 'Grupo Revelação', 'ZHU',
   'Jack Œ', 'Cash Cash', 'SDP', 'Ajaxx', 'Veronica Maggio',
   'Mikky Ekko', 'Headie One', 'Phoenix', 'HOYO-MiX', 'John Coltrane',
   'Motionless In White', 'Alligatoah', 'Alina Baraz', 'Janet Jackson', 'The Mamas & The Papas',
   'American Authors', 'Good Charlotte', 'Masked Wolf', 'Heroes Del Silencio', 'Nine Inch Nails',
   'Current Joys', 'Abel Pintos', 'December Avenue', 'YOVNGCHIMI', 'Heuss L\'enfoiré',
   'Standly', 'Remmy Valenzuela', 'Judas Priest', 'FKJ', 'Andy Williams',
   'Boza', 'N.W.A.', 'Paolo Nutini', 'Yiruma', 'O Rappa',
   'Kansas', 'Ovi', 'Neo Beats', 'PXNDX', 'Tom Grennan',
   'Fugees', 'Ramones', 'Dewa 19', 'Kris Kross Amsterdam', 'Mc Rodrigo do CN',
   'Lyodra', 'BLANCO', 'Ben E. King', 'Dillon Francis', 'Boston',
   'The Head And The Heart', 'Cascada', 'Elderbrook', 'Delacruz', 'Zack Tabudlo',
   'Leonard Cohen', 'Sheck Wes', 'Sofi Tukker', 'Fuse ODG', 'Mabel Matiz',
   'Tammi Terrell', 'Nayer', 'Men At Work', 'grandson', 'New Order',
   'Ernia', 'José González', 'YBN Nahmir', 'Hoobastank', 'Big One',
   'Bushido', 'The Wiggles', 'Ícaro e Gilmar', 'Stone Sour', 'Money Man',
   'Paulina Rubio', 'Asking Alexandria', 'NOTD', 'Maggie Lindemann', '112',
   'Maneva', 'Marisela', 'Snow', 'DeJ Loaf', 'Amanda Seyfried',
   'Still Woozy', 'Dave Matthews Band', 'El Cuarteto De Nos', 'Duncan Laurence', 'Kaskade',
   'Perera DJ', 'Nightwish', 'Björn Skifs', 'Smino', 'Marc E. Bassy',
   'HONNE', 'Twista', 'La K\'onga', 'Los Legendarios', 'Bruno Martini',
   'Fiersa Besari', 'Nothing But Thieves', 'Eduardo Costa', 'Flow G', 'Yellow Claw',
   'Rush', 'Shekhar Ravjiani', 'Foals', 'Al Green', 'Kako',
   'Sonder', 'Massive Attack', 'Tribo da Periferia', 'Brett Eldredge', 'Nusrat Fateh Ali Khan',
   'CYRIL', 'Project Pat', 'Emis Killa', 'Staind', 'The Wombats',
   'Like Mike', 'Patricio Rey y sus Redonditos de Ricota', 'Father John Misty', 'Los Acosta', 'Diana Ross',
   'Caamp', 'LUM!X', 'Trap Capos', 'Russ Millions', 'K-391',
   'Neon Trees', 'Estelle', 'Young Cister', 'Molotov', 'Megan Moroney',
   'Joe Hisaishi', 'Brooke Ligertwood', 'Sleeping With Sirens', 'Forrest Frank', 'Mc Kadu',
   'Thousand Foot Krutch', 'Mike Bahía', 'Mt. Joy', 'Sticky Fingers', 'Enjambre',
   'Scooter', 'MC LUUKY', 'Chino & Nacho', 'James Horner', 'Matheus Fernandes',
   'The Temper Trap', 'The Jordanaires', 'Rob Zombie', 'AlunaGeorge', 'iamjakehill',
   'AWOLNATION', 'Bryce Vine', 'Gavin James', 'The Prodigy', 'Sub Urban',
   'Hov1', 'Tom Misch', 'KATSEYE', 'Nico & Vinz', 'El Makabelico',
   'Bone Thugs-N-Harmony', 'JACKBOYS', 'Sukhwinder Singh', 'Chase & Status', 'Granular',
   'Faye Webster', 'August Alsina', 'Duman', 'The Cardigans', 'Death Cab for Cutie',
   'Iron & Wine', 'Snakehips', 'Yebba', 'Nessa Barrett', 'TobyMac',
   'Boy Wonder CF', 'Shaan', 'Amenazzy', 'Catfish and the Bottlemen', 'K.I.Z',
   'Cup of Joe', 'IZA', 'Crowded House', 'Elvis Crespo', 'Fedez',
   'Yeah Yeah Yeahs', 'Haricharan', 'ANNA', 'Josman', 'Payal Dev',
   'Nemzzz', 'Hiphop Tamizha', 'Fernando & Sorocaba', 'Daughtry', 'DRAM',
   'Brandy', 'Boomdabash', 'Sheryl Crow', 'Shinda Kahlon', 'Mc Pedrinho',
   'Petit Biscuit', 'DJ BOY', 'Dirty Heads', 'Siddhartha', 'Auli\'i Cravalho',
   'Skank', 'Duckjay', 'Mecano', 'El Bogueto', 'The Wanted',
   'Belanova', 'Binomio de Oro de América', 'Anna Kendrick', 'Fito Paez', 'Lecrae',
   'Motörhead', 'Alle Farben', 'Felipe Araújo', 'Gur Sidhu', 'Celia Cruz',
   'Bruno Major', 'KSHMR', 'Dylan Scott', 'Adriel Favela', 'Mazzy Star',
   'Farid Bang', 'Aqua', 'Placebo', 'Josh A', 'Pancho Barraza',
   'Hank Williams', 'DAY6', 'Tay-K', 'Conrad Sewell', 'Palak Muchhal',
   'Vasco Rossi', 'Djavan', 'LEA', 'Bonobo', 'Malik Montana',
   'Leto', 'Phantogram', 'Fleet Foxes', 'CORPSE', 'Lucky Brown',
   'Fito y Fitipaldis', 'Gibbs', 'Frankie Ruiz', 'Abhijeet', 'Asha Bhosle',
   'Eddie Santiago', 'Thamarai', 'Abraham Mateo', 'Colter Wall', 'Clave Especial',
   'Slayer', 'Kristen Bell', 'Millonario', 'BlocBoy JB', 'DJ Oreia',
   'Iyaz', 'Xzibit', 'Billy Talent', 'Jatin-Lalit', 'Josh Turner',
   'Quebonafide', 'Stephanie Beatriz', 'Clayton & Romário', 'Michael Kiwanuka', 'sanah',
   'Lifehouse', 'John Summit', 'Modest Mouse', 'Di Proposito', 'SLANDER',
   'Benny Benassi', 'Ace of Base', 'Projota', 'In Flames', 'Eve',
   'Espinoza Paz', 'Third Eye Blind', 'Gipsy Kings', 'Lil\' Kim', 'Run-D.M.C.',
   'Barry White', 'Chet Faker', 'R.K.M & Ken-Y', 'Starship', 'Nicky Romero',
   'Yung Lean', 'Popcaan', 'Jeff Buckley', 'Showtek', 'Lauren Alaina',
   'Brendon Urie', 'OHGEESY', 'Anthony Ramos', 'Seu Jorge', 'Alan Menken',
   'Shouse', 'Priya Saraiya', 'Edicion Especial', 'Vald', 'Tungevaag',
   'João', 'Afgan', 'Zola', 'Pailita', 'La Quinta Estacion',
   'Lauren Spencer Smith', 'Dedublüman', 'Darkiel', 'Mc Daniel', 'Theory of a Deadman',
   'Dawid Podsiadło', 'Natanzinho Lima', 'Miksu / Macloud', 'Social House', 'Bleachers',
   'Jósean Log', 'Oscar Peterson', 'James Morrison', 'Faith Evans', 'Tony Effe',
   'BANNERS', 'Tiziano Ferro', 'Panteon Rococo', 'Rich Music LTD', 'Sagopa Kajmer',
   'Lasso', 'Kidd Voodoo', 'Gülsen', 'BABYMONSTER', 'Jack & Jack',
   'Plain White T\'s', 'Yann Tiersen', '1nonly', 'Chitãozinho & Xororó', 'Yuuri',
   'Tarkan', 'The Animals', 'For Revenge', 'Cruz Cafuné', 'Bvga Beatz',
   'NATHY PELUSO', 'Rosa Linn', 'Tony Bennett', 'Lijpe', 'JJ Lin',
   'Jadakiss', 'Oki', 'Ray LaMontagne', 'John Mellencamp', 'Little Big Town',
   'NEEDTOBREATHE', 'Blood Orange', 'Broiler', 'Jamule', 'BIN',
   'Treaty Oak Revival', 'Josylvio', 'Cedric Gervais', 'R. City', 'Gavin DeGraw',
   'Camilo Sesto', 'Pyotr Ilyich Tchaikovsky', 'Dhvani Bhanushali', 'Warren Zeiders', 'GAYLE',
   'Salim–Sulaiman', 'New West', 'Stevie Nicks', 'The Cars', 'The Piano Guys',
   'TAEYEON', 'Shindy', 'DELLAFUENTE', 'Bakermat', 'Claude Debussy',
   'Rocco Hunt', 'The Outfield', 'Set It Off', 'Aimer', 'Gaab',
   'MC G15', 'Royal Blood', 'Sameer Anjaan', 'The Ronettes', 'FLETCHER',
   'Vanessa Hudgens', 'Elle King', 'Killer Mike', 'NDX A.K.A.', 'Jawsh 685',
   'Dharius', 'Gloria Estefan', 'Jim Croce', 'Feby Putri', 'Creepy Nuts',
   'DJ Glenner', 'Russell Dickerson', 'Bread', 'Parker McCollum', 'A Great Big World',
   'AK AUSSERKONTROLLE', 'Au/Ra', 'Famous Dex', 'ROZES', 'Billie Holiday',
   'Neck Deep', 'Aleks Syntek', 'Hikaru Utada', 'Chefin', 'MONSTA X',
   'Borges', 'Mijares', 'Skusta Clee', 'Hande Yener', 'TIAGO IORC',
   'Miles Davis', 'Mariah Angeliq', 'Murda', 'Joe Cocker', 'Belo',
   'Ben Platt', 'Love Funk', 'La Sonora Dinamita', 'OBOY', 'Mc Jacaré',
   'Chance Peña', 'Mr Eazi', 'Stan Getz', 'Kaaris', 'Roy Woods',
   'Parokya Ni Edgar', 'Ivy Queen', 'Snøw', 'MadMan', 'Bipolar Sunshine',
   'Whethan', 'Joe', 'Los Alegres Del Barranco', 'Intense', 'FIFTY FIFTY',
   'Nando Reis', 'EDEN', 'Casting Crowns', 'Boosie Badazz', 'Dayglow',
   'João Gilberto', 'Aaliyah', 'Redman', 'Mase', 'Smokepurpp',
   'Snoh Aalegra', 'Lanek', 'Phil Wickham', 'mike.', 'mxmtoon',
   'LeeHi', 'John Travolta', 'BNXN', 'Roop Kumar Rathod', 'Banda Pequeños Musical',
   'Rachel Platten', 'Ankit Tiwari', 'Bhavi', 'Paloma Mami', 'Interpol',
   'Killswitch Engage', 'LX', 'EARTHGANG', 'AOA', 'MAMAMOO',
   'Müslüm Gürses', 'Edward Sharpe & The Magnetic Zeros', 'Fourtwnty', 'Naughty Boy', 'George Henrique & Rodrigo',
   'Stick Figure', 'Meryl Streep', 'Syd', 'Commodores', 'MHD',
   'Neeraj Shridhar', 'Erik Satie', 'Kendo Kaponi', 'Take That', 'cakal',
   'Aaron May', 'Chris MC', 'Europe', 'Beach Weather', 'Jorge Drexler',
   'Eric Bellinger', 'Sam Barber', 'Código FN', 'Cultura Profética', 'Sixpence None The Richer',
   'Whitesnake', 'Helene Fischer', 'reidenshi', 'Virgoun', 'Dan Caplen',
   'Tony Aguirre', 'Keinemusik', 'Ghostface Killah', 'Carlos Baute', 'Rob Thomas',
   'Ahmet Kaya', 'Jeet Gannguli', 'Nicky Youre', 'CORBAL', 'Irama',
   'REO Speedwagon', 'Jerry Rivera', 'Lucy Dacus', 'Young Stoner Life', 'Chevelle',
   'Berliner Philharmoniker', 'Dusty Springfield', 'Lagum', 'LEGADO 7', 'STARSET',
   'D12', 'Loreen', 'L-Gante', 'Vegedream', 'Sevdaliza',
   'shy martin', 'Chris Lake', 'Gnarls Barkley', 'DIVINE', 'The Andrews Sisters',
   'Francesco Yates', 'S. Janaki', 'Marisa Monte', 'Ivete Sangalo', 'Charly García',
   'Eazy-E', 'José Luis Perales', 'K CAMP', 'Y2K', 'Mos Def',
   'Yüzyüzeyken Konuşuruz', 'Baby Tate', 'Aditya Rikhari', 'Lilly Wood and The Prick', 'ATL Jacob',
   'Al James', 'PRO8L3M', 'R. D. Burman', 'Sadhana Sargam', 'Los Caminantes',
   'Luccas Carlos', 'Comethazine', 'Savage Garden', 'Stereophonics', 'Michael Bolton',
   'ILLIT', 'CAPO', 'Dalmata', 'Nina Chuba', 'Rick Astley',
   'Dolu Kadehi Ters Tut', 'Ski Aggu', 'Los Huracanes del Norte', 'Daughter', 'Louis The Child',
   'Inspector', 'Richy Mitch & The Coal Miners', 'Zeeba', 'Declan McKenna', 'Ying Yang Twins',
   'Kailash Kher', 'Alex Ubago', 'Hannah Montana', 'Jonna Fraser', 'Justin Moore',
   'Caio Luccas', 'Lloyd Banks', 'Kina Grannis', 'Robyn', 'Mura Masa',
   'Diana Krall', 'Krono', 'Kid Yugi', 'DYSTINCT', 'Mc Lele JP',
   'Jazeek', 'Aaron Smith', 'Howard Shore', 'Kizzy', 'La Joaqui',
   'FiNCH', 'Victoria Monet', 'K.Flay', 'Maelo Ruiz', 'Mahmood',
   'KeBlack', 'Pol Granch', 'TREASURE', 'FKA twigs', 'Travie McCoy',
   'Kelis', 'Szpaku', 'Sampha', 'DVBBS', 'Clams Casino',
   'Jaideep Sahni', 'LL COOL J', 'Chandler Moore', 'Michael Giacchino', 'Jovanotti',
   'Anson Seabra', 'Cody Jinks', 'ZillaKami', 'Kasabian', 'Damas Gratis',
   'Edward Maya', 'Chet Baker', 'Bakar', 'The Supremes', 'Fuego',
   'Nardo Wick', 'Raça Negra', 'Franglish', 'Herencia de Patrones', 'Mandy Moore',
   'Soprano', 'Corinne Bailey Rae', 'Warren G', 'Janieck', 'Cast of EPIC: The Musical',
   'Tom Rosenthal', 'A R I Z O N A', 'Omarion', 'Big Time Rush', 'Tenacious D',
   'Clinton Kane', 'Vicentico', 'Silvio Rodríguez', 'Vidyasagar', 'INTERWORLD',
   'Frah Quintale', 'Madcon', 'Mindless Self Indulgence', 'Super Yei', 'Białas',
   'ERNEST', 'Sabrina Claudio', 'Dhruv', 'Frank Miami', 'HVME',
   'Marcos & Belutti', 'BloodPop®', 'BABYMETAL', 'First Aid Kit', 'TheFatRat',
   'ATB', 'Murillo e LT no Beat', 'Halestorm', 'TJ Monterde', 'Hillsong Young & Free',
   'A$AP Mob', 'Leony', 'Matt Maltese', 'The Magician', 'Mohammed Rafi',
   'Bill Evans', 'Toni Braxton', 'Los Angeles De Charly', 'AgroPlay', 'Bishop Briggs',
   'SiR', 'Olexesh', 'Anuradha Paudwal', 'Jay Park', 'Liberación',
   'WWE', 'Parcels', 'Grupo Arriesgado', 'Too $hort', 'SUGA',
   'Silent Sanctuary', 'Emir Can İrek', 'El Bebeto', 'Pradeep Kumar', 'Donna Summer',
   'Kenny G', 'Frankie Valli', 'Dakota', 'Zoe Wees', 'Adam Port',
   'Sevn Alias', 'Los Bunkers', 'Blackstreet', 'TrapLaudo', 'Cookin\' On 3 Burners',
   'Ólafur Arnalds', 'BANKS', 'Jordin Sparks', 'PSY', 'Gazzelle',
   'Dropkick Murphys', 'Vanessa Carlton', 'Enigma Norteño', '01099', 'Nick Cave & The Bad Seeds',
   'Tony Boy', 'Eason Chan', 'Eric Prydz', 'Whiskey Myers', 'Claptone',
   'Pixote', 'Joy Division', 'Ele A El Dominio', 'Håkan Hellström', 'Young Buck',
   'Jonathan Groff', 'for KING & COUNTRY', 'Shenseea', 'Juelz Santana', 'G-Unit',
   'Diego Torres', 'Kukon', 'NCT U', 'Slim Jxmmi', 'Gminxr',
   'Kool Savas', 'Luther Vandross', 'Nightcrawlers', 'Brandi Carlile', 'Divya Kumar',
   'Manuel Carrasco', 'Ximena Sariñana', 'Sonny Fodera', 'Naza', 'Marc Seguí',
   'Ken-Y', 'Fenix Flexin', 'Chase Rice', 'El Canto Del Loco', 'Barbra Streisand',
   'EST Gee', 'Seal', 'hey daisy', 'Haftbefehl', 'G-DRAGON',
   'Parson James', 'Rá Saia Rodada', 'KITSCHKRIEG', 'Cuisillos De Arturo Macias', 'Allman Brothers Band',
   'Vitão', 'Takagi & Ketra', 'Shy Glizzy', 'Mc Negão Original', 'Gurlez Akhtar',
   'James Newton Howard', 'William Singe', 'Lamb of God', 'Kizz Daniel', 'Academy of St. Martin in the Fields',
   'Plies', 'Chris Isaak', 'Böhse Onkelz', 'CamelPhat', 'Coyote Beatz',
   'Kevin', 'Andmesh', 'Night Skinny', 'Haddaway', 'Víctor Manuelle',
   'Ravyn Lenae', 'Regina Spektor', 'George Benson', 'Kizo', 'Broederliefde',
   'Andrew Choi', 'The Shins', 'Elliott Smith', 'Big Thief', 'Zaz',
   'Zuna', 'Lil Xan', 'Run The Jewels', 'Dance Gavin Dance', 'Maher Zain',
   'Alabama', 'Bladee', 'Hopsin', 'Faith Hill', 'King Princess',
   'Alice Cooper', 'Hilltop Hoods', 'Artie 5ive', 'Rodney Atkins', 'Héctor Lavoe',
   '.Feast', 'Vicetone', 'Hades66', 'The Velvet Underground', 'BHZ',
   'Ramon Ayala Y Sus Bravos Del Norte', 'Young Money', 'Sam Martin', 'Gorgon City', 'salvia palth',
   'Matt Simons', 'Four Tops', 'Muni Long', 'Rondodasosa', 'Emily Warren',
   'Fredo', 'Freeze corleone', 'Don Henley', 'Vanesa Martín', 'José Feliciano',
   'Shweta Mohan', 'Thomas Bergersen', 'Adrianne Lenker', 'Swizz Beatz', 'High School Musical Cast',
   'Klingande', 'Danny Elfman', 'Vybz Kartel', 'Isadora Pompeo', 'Mark Ambor',
   'Exaltasamba', 'BM', 'A-Trak', 'Banda Machos', 'Sujatha',
   'GOT7', 'Andy Rivera', 'Marco Mengoni', 'iZaak', 'Armandinho',
   'Preme', 'Chimbala', 'Andrew Lloyd Webber', 'Ina Wroldsen', 'Rizky Febian',
   'Parkway Drive', 'Brothers Osborne', 'Mr.Kitty', 'Yellowcard', 'Trettmann',
   'Randy Travis', 'Grupo Codiciado', 'Bootsy Collins', 'Del The Funky Homosapien', 'Rajat Nagpal',
   'Don McLean', 'Deepend', 'Shaarib Toshi', 'Mozzy', 'Achille Lauro',
   'Renée Rapp', 'Wings', 'Mc Delux', 'La T y La M', 'Nate Smith',
   'Sertab Erener', 'Joey Montana', 'Payung Teduh', 'Justice', 'SG Lewis',
   'Dzeko', 'NEIKED', 'CJ', 'El Trono de Mexico', 'Janis Joplin',
   'Hivi!', 'Denny Caknan', 'K/DA', 'Tom Jones', 'Murda Beatz',
   'Andrés Cepeda', 'Eric Chou', 'Cochise', 'Surf Mesa', 'Shirin David',
   'Vanessa Da Mata', 'Yot Club', 'Iggy Pop', 'JoJo', 'Miel San Marcos',
   'Sofiane', 'Eliza Doolittle', 'Architects', 'Naresh Iyer', 'Yalın',
   'Dj GM', 'Birdman', 'Engenheiros Do Hawaii', 'Bagua Records', 'Guyon Waton',
   'Cream', 'Trivium', 'Serdar Ortaç', 'Nathan Evans', 'Giggs',
   'Elodie', 'Curren$y', 'Lou Reed', 'Annalisa', 'Aphex Twin',
   'Sturgill Simpson', 'Uzielito Mix', 'Yung Bleu', 'ItaloBrothers', 'Strawberry Guy',
   'Porter Robinson', 'Ennio Morricone', 'Yovie & Nuno', 'Lulu Santos', 'Action Bronson',
   'Neoni', 'Raekwon', 'Noyz Narcos', 'Ebru Gündeş', 'El Malilla',
   'Glenn Fredly', 'Ginuwine', 'Two Steps from Hell', 'Blue Öyster Cult', 'Gus Dapperton',
   'João Bosco & Vinícius', '4 Non Blondes', 'J-AX', 'Passion Pit', 'Lucky Daye',
   'Misfits', 'Suki Waterhouse', 'Jeremy Soule', 'Marcos Witt', 'Simge',
   'Common', 'Fatboy Slim', 'RK', 'MC Paulin da Capital', 'Einár',
   'Dizzee Rascal', 'Yung Beef', 'Foxes', 'Bugzy Malone', 'Saint Motel',
   'Dom Dolla', 'El Jordan 23', 'Kip Moore', 'Cafuné', 'Christopher Cross',
   'Rico Nasty', 'Young Igi', 'Raj Shekhar', 'Cassie', 'Noah',
   'Perry Como', 'A Perfect Circle', 'Panter Bélico', 'XG', 'José Alfredo Jimenez',
   'HIRAIDAI', 'Kaash Paige', 'Teoman', 'Sawano Hiroyuki', 'That Mexican OT',
   'Matt Maeson', 'St. Vincent', 'bôa', 'Dubdogz', 'Ben Harper',
   'Lil Jon & The East Side Boyz', 'Los Prisioneros', 'Tai Verdes', 'The Lonely Island', 'Gulzar',
   'Young M.A', 'Luciano Pavarotti', 'The Cinematic Orchestra', 'FAST BOY', 'Lali',
   'Adie', 'Paul Kalkbrenner', 'Jazmine Sullivan', 'Yung Joc', 'Laylow',
   'Girls\' Generation', 'Simba La Rue', 'Sam Haft', 'Leiva', 'BJ The Chicago Kid',
   'Shakthisree Gopalan', 'Rebelution', 'Hollow Coves', 'Timbiriche', 'ACRAZE',
   'Hoodie Allen', 'Sam Fischer', 'Mitchell Tenpenny', 'Against The Current', 'Crush',
   'Loyle Carner', 'Tash Sultana', 'MC Rick', 'Parov Stelar', 'Diego Verdaguer',
   'Eraserheads', 'Chaka Khan', 'Bresh', 'Caloncho', 'Charlie Wilson',
   'Los Cafres', 'Sergio Vega "El Shaka"', 'Ari Lennox', 'LXNGVX', 'Alabama Shakes',
   'Landon Cube', 'Izi', 'Massimo Pericolo', 'Solange', 'Bonn',
   'Todah Music', 'Los Panchos', 'Paula Fernandes', 'Huey Lewis & The News', 'Adam Lambert',
   'André 3000', 'Jamby El Favo', 'Kubi Producent', 'Wolfine', 'Pretenders',
   'Toosii', 'Pawan Singh', 'Niro', '3OH!3', 'Nicole Scherzinger',
   'Puddle Of Mudd', 'Gojira', 'Bellakath', 'Culture Club', 'Veysel',
   'Konshens', 'Loredana', 'kent', 'Vengaboys', 'Gloria Gaynor',
   'Harrdy Sandhu', 'HRVY', 'CAKE', 'KC & The Sunshine Band', 'India Martinez',
   'Peter Gabriel', 'Mumuzinho', 'Los Gemelos De Sinaloa', 'MXZI', 'Travis Tritt',
   'Monica', 'Airbag', 'Fast & Furious: The Fast Saga', 'Batuflex', 'Bobby Helms',
   'The Chemical Brothers', 'ARASHI', 'Shashaa Tirupati', 'VINAI', 'Zé Ramalho',
   'The Isley Brothers', 'Mc Lipi', 'Pia Mia', 'Leonardo', 'Reykon',
   'iKON', 'ROLE MODEL', 'Charly Black', 'Marcela Gandara', 'Ronan Keating',
   'Vitor Kley', 'Mark Forster', 'Ramirez', 'Digga D', 'DallasK',
   'Buena Vista Social Club', 'Vika Jigulina', 'Poison', '6arelyhuman', 'Tommee Profitt',
   'Ol\' Dirty Bastard', 'Henrique & Diego', 'Los Pericos', 'Nancy Sinatra', 'Cherish',
   'K. J. Yesudas', 'Electric Callboy', 'Juju', 'Los Caligaris', 'Brian Eno',
   'YFN Lucci', 'Callejeros', '311', 'The Avett Brothers', 'Lartiste',
   'Westside Gunn', 'Soft Cell', 'Passion', 'Peggy Gou', 'El-P',
   'Dionela', 'Javier Rosas Y Su Artillería Pesada', 'Fidel Rueda', 'Ludwig Göransson', 'Ariis',
   'Fred De Palma', 'Olamide', 'Pendulum', 'Julien Baker', 'Iwan Fals',
   'Amaarae', 'Bad Wolves', 'Eddie Vedder', 'Yuri', 'The Red Jumpsuit Apparatus',
   'Norma Jean Martine', 'Emicida', 'Sophie Ellis-Bextor', 'Vignesh Shivan', 'Frankie Valli & The Four Seasons',
   'Yura Yunita', 'Hunter Hayes', 'Three 6 Mafia', 'ArrDee', 'Marina Sena',
   'tatool', 'Ñejo & Dalmata', 'TAEYANG', 'Matthew Koma', 'Gilli',
   'Jairo Vera', 'The Band', 'Yunk Vino', 'Vierra', 'KEVVO',
   'Cher Lloyd', 'Migrantes', 'Addison Rae', 'COIN', 'The Backseat Lovers',
   'Toledo', 'Mi Banda El Mexicano', 'Aldo Trujillo', 'Mario Winans', 'Stevie Ray Vaughan',
   'Vigiland', 'GoonRock', 'Andrew Underberg', 'Jota Quest', 'Kabilan',
   'DigDat', 'Mayday Parade', 'Natalie Imbruglia', 'Witt Lowry', 'Extremoduro',
   'Ella Langley', 'JPEGMAFIA', 'Joan Jett & the Blackhearts', 'Jet', 'Madame',
   'Die Antwoord', 'Los Rehenes', 'Renée Elise Goldsberry', 'Anthony Santos', 'Kenya Grace',
   'The Hollies', 'Metronomy', 'SHINee', 'Seyi Vibez', 'Kyan',
   '»abson', 'Vitor Fernandes', 'Snelle', 'Mako', 'Troy',
   'Danny Brown', 'Los Yonic\'s', 'Paky', '347aidan', 'Justine Skye',
   'Benjamin Ingrosso', 'Charles Aznavour', 'Ryan Riback', 'Daniel Hope', 'Amr Diab',
   'Gang Starr', 'Duster', 'YouNotUs', 'Neo Pistea', 'Felipe e Rodrigo',
   'Sushin Shyam', 'Alta Consigna', 'Kiana Ledé', 'Gilberto Gil', 'Roar',
   'Redimi2', 'Jessie Ware', 'Marco Barrientos']
# Out:
# <>:193: SyntaxWarning: invalid escape sequence '\ '
# <>:193: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-3076774465.py:193: SyntaxWarning: invalid escape sequence '\ '
#   "ZZ Top", "ONE OK ROCK", "Manu Chao", "David Kushner", "Axwell /\ Ingrosso", "The Kooks", "Hariharan",

# %%
popular_songs = search(popular_artists, songs_of_art=15)
popular_songs
# Out:
# [{'id': 3315890,
#   'title': 'God’s Plan',
#   'artist': 'Drake',
#   'page_views': 9933595,
#   'url': 'https://genius.com/Drake-gods-plan-lyrics'},
#  {'id': 3807759,
#   'title': 'In My Feelings',
#   'artist': 'Drake',
#   'page_views': 7853393,
#   'url': 'https://genius.com/Drake-in-my-feelings-lyrics'},
#  {'id': 2263723,
#   'title': 'Hotline Bling',
#   'artist': 'Drake',
#   'page_views': 7264399,
#   'url': 'https://genius.com/Drake-hotline-bling-lyrics'},
#  {'id': 2450584,
#   'title': 'One Dance',
#   'artist': 'Drake',
#   'page_views': 6288104,
#   'url': 'https://genius.com/Drake-one-dance-lyrics'},
#  {'id': 200546,
#   'title': 'Hold On, We’re Going Home',
#   'artist': 'Drake',
#   'page_views': 5655239,
#   'url': 'https://genius.com/Drake-hold-on-were-going-home-lyrics'},
#  {'id': 703654,
#   'title': 'Know Yourself',
#   'artist': 'Drake',
#   'page_views': 5388383,
#   'url': 'https://genius.com/Drake-know-yourself-lyrics'},
#  {'id': 2266961,
# ...

# %%
df = pd.DataFrame(popular_songs)

# %%
df.to_excel("genius.xlsx")

# %%
df.to_csv("genius.csv")

# %%
df.head(10)
# Out:
#          id                      title artist  page_views  \
# 0   3315890                 God’s Plan  Drake     9933595
# 1   3807759             In My Feelings  Drake     7853393
# 2   2263723              Hotline Bling  Drake     7264399
# 3   2450584                  One Dance  Drake     6288104
# 4    200546  Hold On, We’re Going Home  Drake     5655239
# 5    703654              Know Yourself  Drake     5388383
# 6   2266961               Back To Back  Drake     5278120
# 7  10356318             Family Matters  Drake     4858297
# 8    196551                     All Me  Drake     4141174
# 9    217270                  From Time  Drake     4027264
#
#                                                  url
# 0          https://genius.com/Drake-gods-plan-lyrics
# 1     https://genius.com/Drake-in-my-feelings-lyrics
# 2      https://genius.com/Drake-hotline-bling-lyrics
# 3          https://genius.com/Drake-one-dance-lyrics
# 4  https://genius.com/Drake-hold-on-were-going-ho...
# ...

# %%
df.tail(10)
# Out:
#             id                                              title  \
# 44687  1811738                                   Ven Espiritu Ven
# 44688  2210114                                Lo Único Que Quiero
# 44689  2190859                    Al Que Está Sentado En El Trono
# 44690  2259715  Exaltado Estas (En Vivo) [feat. Marco Barrientos]
# 44691  2052682                                  Nada es imposible
# 44692  2126698                           Ven, Es Hora De Adorarle
# 44693  2059444                                       Rey de Reyes
# 44694  1969295                             Eres rey de los cielos
# 44695   831577                        El Señor Está En Este Lugar
# 44696  2056186                                De Gloria En Gloria
#
#                  artist  page_views  \
# 44687  Marco Barrientos        6026
# 44688  Marco Barrientos        5477
# 44689  Marco Barrientos           0
# 44690   Miel San Marcos           0
# 44691  Marco Barrientos           0
# ...
